# %%
#Exercice 4

from PIL import Image
import numpy as np
imgpil = Image.open("iguane.jpg")  
img = np.array(imgpil)
print(img.shape)#Cela va nous donner 480 de largeur pour 639 de longueur et nous préciser le nombre de plans qui est de 3
# Out:
# (480, 639, 3)

# %%
#Exercice 6

from PIL import Image,ImageDraw
from IPython.display import display

#taille image
largeur= 639
hauteur= 480
#On réutilise les données obtenues dans l'exercice 4

img=Image.open("iguane.jpg")
for x in range (639):
    for y in range (480):
        r,v,b=img.getpixel((x,y))
        g = int((r+v+b)/3)
        img.putpixel((x,y),(g,g,g))
        #print(x,y,nr,nv,nb)
img.save("iguane.jpg")
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=639x480 at 0xA5F0C8>
